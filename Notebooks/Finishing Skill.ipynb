# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
league = 'Championship'
if league == 'Premier League':
    id = 91
    df = pd.read_html(f'https://fbref.com/en/comps/9/{league[0]}-{league[1]}-Stats', attrs = {"id" : f"results2023-2024{id}_overall"})[0]
else:
    id = 101
    df = pd.read_html(f'https://fbref.com/en/comps/10/{league}-Stats', attrs = {"id" : f"results2023-2024{id}_overall"})[0]

# %%
df_xG_GF = df[['Squad', 'xG','xGA','GF','GA']]
df_xG_GF.rename(columns={'Squad':'Team'}, inplace=True)
# Out:
# C:\Users\dmsta\AppData\Local\Temp\ipykernel_19280\1053559381.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_xG_GF.rename(columns={'Squad':'Team'}, inplace=True)

# %%
df_PSxG = pd.read_html(f'https://fbref.com/en/comps/10/{league}-Stats', attrs = {"id" : "stats_squads_keeper_adv_against"})[0]

# %%
df_PSxGA = pd.read_html(f'https://fbref.com/en/comps/10/{league}-Stats', attrs = {"id" : "stats_squads_keeper_adv_for"})[0]

# %%
df_PSxG.columns = ['_'.join(col).strip() for col in df_PSxG.columns.values]
df_PSxGA.columns = ['_'.join(col).strip() for col in df_PSxGA.columns.values]

# %%
df_PSxG
# Out:
#    Unnamed: 0_level_0_Squad  Unnamed: 1_level_0_# Pl  Unnamed: 2_level_0_90s  \
# 0        vs Birmingham City                        2                    46.0
# 1              vs Blackburn                        2                    46.0
# 2           vs Bristol City                        1                    46.0
# 3           vs Cardiff City                        3                    46.0
# 4          vs Coventry City                        2                    46.0
# 5           vs Huddersfield                        3                    46.0
# 6              vs Hull City                        2                    46.0
# 7           vs Ipswich Town                        2                    46.0
# 8           vs Leeds United                        3                    46.0
# 9         vs Leicester City                        2                    46.0
# 10         vs Middlesbrough                        2                    46.0
# 11              vs Millwall                        2                    46.0
# 12          vs Norwich City                        2                    46.0
# 13       vs Plymouth Argyle                        2                    46.0
# 14               vs Preston                        2                    46.0
# 15                   vs QPR                        2                    46.0
# 16         vs Rotherham Utd                        2                    46.0
# 17        vs Sheffield Weds                        3                    46.0
# 18           vs Southampton                        2                    46.0
# 19            vs Stoke City                        4                    46.0
# 20            vs Sunderland                        2                    46.0
# 21          vs Swansea City                        1                    46.0
# 22               vs Watford                        2                    46.0
# 23             vs West Brom                        1                    46.0
#
#     Goals_GA  Goals_PKA  Goals_FK  Goals_CK  Goals_OG  Expected_PSxG  \
# 0         50          2         2         5         2           50.5
# 1         60          0         0         4         1           59.7
# 2         53          7         1         9         1           52.1
# 3         53          2         1        17         5           43.4
# 4         70          3         2         9         4           62.9
# 5         48          1         0         8         2           43.7
# 6         68          4         1         9         0           65.8
# 7         92          2         0        12         4           76.7
# 8         81          7         0         7         3           81.1
# 9         89         12         1         6         1           89.6
# 10        71          2         1         5         2           72.0
# 11        45          1         2         8         1           43.4
# 12        79          2         3        11         3           65.0
# 13        59          1         2         2         1           55.0
# 14        56          3         0         5         3           48.4
# 15        47          1         0         5         3           40.6
# 16        37          2         0         5         0           29.7
# 17        44          0         0         5         1           44.9
# 18        87          4         1        12         2           88.6
# 19        49          1         1         8         3           48.9
# 20        52          6         1         7         1           59.7
# 21        59          4         1         9         2           58.6
# 22        61          1         0         9         0           56.7
# 23        70          5         2         6         2           59.8
#
#     Expected_PSxG/SoT  ...  Passes_AvgLen  Goal Kicks_Att  Goal Kicks_Launch%  \
# 0                0.28  ...           32.4             350                48.3
# 1                0.31  ...           33.7             362                47.5
# 2                0.28  ...           31.1             359                38.2
# 3                0.24  ...           29.6             331                36.6
# 4                0.32  ...           33.7             375                47.7
# 5                0.27  ...           33.4             360                45.0
# 6                0.27  ...           32.7             353                49.0
# 7                0.30  ...           34.0             375                49.1
# 8                0.32  ...           36.5             385                54.5
# 9                0.34  ...           33.0             459                44.0
# 10               0.31  ...           32.1             331                40.2
# 11               0.28  ...           32.1             308                45.1
# 12               0.32  ...           34.6             371                52.0
# 13               0.27  ...           32.7             331                40.5
# 14               0.33  ...           34.4             312                32.4
# 15               0.23  ...           31.8             356                41.6
# 16               0.27  ...           30.9             324                36.1
# 17               0.31  ...           34.0             331                42.6
# 18               0.35  ...           36.1             373                50.9
# 19               0.28  ...           34.9             377                45.4
# 20               0.26  ...           34.5             369                50.7
# 21               0.31  ...           33.7             362                47.2
# 22               0.30  ...           30.8             385                43.1
# 23               0.35  ...           36.6             336                56.5
#
#     Goal Kicks_AvgLen  Crosses_Opp  Crosses_Stp  Crosses_Stp%  Sweeper_#OPA  \
# 0                39.8          505           28           5.5            66
# 1                38.4          493           36           7.3            59
# 2                33.7          630           36           5.7            93
# 3                33.5          564           32           5.7            66
# 4                38.2          674           40           5.9            51
# 5                36.8          712           43           6.0            77
# 6                40.2          577           31           5.4            77
# 7                40.3          676           60           8.9            46
# 8                41.6          585           19           3.2            49
# 9                37.3          601           34           5.7            55
# 10               35.5          593           39           6.6            59
# 11               36.9          605           44           7.3            45
# 12               41.1          695           42           6.0            54
# 13               35.4          471           26           5.5            76
# 14               32.0          620           49           7.9            59
# 15               37.3          731           44           6.0            54
# 16               32.7          559           35           6.3            43
# 17               36.3          643           42           6.5            44
# 18               40.5          693           44           6.3            45
# 19               37.4          691           40           5.8            47
# 20               40.3          617           49           7.9            52
# 21               38.3          728           46           6.3            58
# 22               36.9          697           32           4.6            47
# 23               44.3          689           34           4.9            46
#
#     Sweeper_#OPA/90  Sweeper_AvgDist
# 0              1.43             16.5
# 1              1.28             16.6
# 2              2.02             16.6
# 3              1.43             17.5
# 4              1.11             13.4
# 5              1.67             15.8
# 6              1.67             16.8
# 7              1.00             12.9
# 8              1.07             15.5
# 9              1.20             15.1
# 10             1.28             14.5
# 11             0.98             14.1
# 12             1.17             14.8
# 13             1.65             17.0
# 14             1.28             15.1
# 15             1.17             13.6
# 16             0.93             14.2
# 17             0.96             14.0
# 18             0.98             13.9
# 19             1.02             15.3
# 20             1.13             14.5
# 21             1.26             16.3
# 22             1.02             14.9
# 23             1.00             15.1
#
# [24 rows x 28 columns]

# %%
df_PSxG = df_PSxG[['Unnamed: 0_level_0_Squad', 'Expected_PSxG']]
df_PSxG.rename(columns={'Unnamed: 0_level_0_Squad': 'Team', 'Expected_PSxG' : 'PSxG'}, inplace=True)
# Out:
# C:\Users\dmsta\AppData\Local\Temp\ipykernel_19280\428416096.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_PSxG.rename(columns={'Unnamed: 0_level_0_Squad': 'Team', 'Expected_PSxG' : 'PSxG'}, inplace=True)

# %%
df_PSxG['Team'] = df_PSxG['Team'].str.split('vs').str[1]
# Out:
# C:\Users\dmsta\AppData\Local\Temp\ipykernel_19280\2568517509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_PSxG['Team'] = df_PSxG['Team'].str.split('vs').str[1]

# %%
df_PSxGA = df_PSxGA[['Unnamed: 0_level_0_Squad', 'Expected_PSxG']]
df_PSxGA.rename(columns={'Unnamed: 0_level_0_Squad': 'Team', 'Expected_PSxG' : 'PSxGA'}, inplace=True)

# %%
df_PSxG['Team'] = df_PSxG['Team'].str.strip()
# Out:
# C:\Users\dmsta\AppData\Local\Temp\ipykernel_19280\501252023.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_PSxG['Team'] = df_PSxG['Team'].str.strip()

# %%
df_PSxG = df_PSxG.merge(df_PSxGA, on='Team')

# %%
df = df_xG_GF.merge(df_PSxG, on='Team')

# %%
df['Finishing Skill %'] = ((df['PSxG'] - df['xG'])/df['xG']) * 100
df['Finishing Skill %'] = df['Finishing Skill %'].round(2)

# %%
df['Finishing Luck %'] = ((df['GF'] - df['PSxG'])/df['PSxG']) * 100
df['Finishing Luck %'] = df['Finishing Luck %'].round(2)

# %%
df['Opp Finishing Skill %'] = ((df['PSxGA'] - df['xGA'])/df['xGA']) * 100
df['Opp Finishing Skill %'] = df['Opp Finishing Skill %'].round(2)

# %%
df['Opp Finishing Luck %'] = ((df['GA'] - df['PSxGA'])/df['PSxGA']) * 100
df['Opp Finishing Luck %'] = df['Opp Finishing Luck %'].round(2)

# %%
df = df[['Team', 'xG', 'PSxG']]

# %%
df['Badge'] = df['Team'].apply(lambda x: f"C:/Users/George/Documents/Football Analytics/Team Logos/{x.lower()}_logo.png")

# %%
df = pd.DataFrame(df)

# %%
df['PSxG - xG'] = df['PSxG'] - df['xG']
df.sort_values(by='PSxG - xG', ascending=False, inplace=True)
df
# Out:
#                Team    xG  PSxG  \
# 3       Southampton  79.8  88.6
# 6         Hull City  57.2  65.8
# 9           Preston  40.7  48.4
# 0    Leicester City  84.9  89.6
# 7     Middlesbrough  68.3  72.0
# 13          Watford  53.2  56.7
# 1      Ipswich Town  74.0  76.7
# 20  Plymouth Argyle  52.3  55.0
# 4      Norwich City  63.0  65.0
# 2      Leeds United  79.5  81.1
# 21  Birmingham City  49.1  50.5
# 10     Bristol City  51.7  52.1
# 12     Swansea City  58.8  58.6
# 11     Cardiff City  43.6  43.4
# 5         West Brom  60.1  59.8
# 15         Millwall  43.9  43.4
# 8     Coventry City  63.8  62.9
# 18        Blackburn  60.9  59.7
# 23    Rotherham Utd  31.6  29.7
# 14       Sunderland  61.7  59.7
# 16              QPR  44.2  40.6
# 22     Huddersfield  48.6  43.7
# 17       Stoke City  54.0  48.9
# 19   Sheffield Weds  50.2  44.9
#
#                                                 Badge  PSxG - xG
# 3   C:/Users/George/Documents/Football Analytics/T...        8.8
# 6   C:/Users/George/Documents/Football Analytics/T...        8.6
# 9   C:/Users/George/Documents/Football Analytics/T...        7.7
# 0   C:/Users/George/Documents/Football Analytics/T...        4.7
# 7   C:/Users/George/Documents/Football Analytics/T...        3.7
# 13  C:/Users/George/Documents/Football Analytics/T...        3.5
# 1   C:/Users/George/Documents/Football Analytics/T...        2.7
# 20  C:/Users/George/Documents/Football Analytics/T...        2.7
# 4   C:/Users/George/Documents/Football Analytics/T...        2.0
# 2   C:/Users/George/Documents/Football Analytics/T...        1.6
# 21  C:/Users/George/Documents/Football Analytics/T...        1.4
# 10  C:/Users/George/Documents/Football Analytics/T...        0.4
# 12  C:/Users/George/Documents/Football Analytics/T...       -0.2
# 11  C:/Users/George/Documents/Football Analytics/T...       -0.2
# 5   C:/Users/George/Documents/Football Analytics/T...       -0.3
# 15  C:/Users/George/Documents/Football Analytics/T...       -0.5
# 8   C:/Users/George/Documents/Football Analytics/T...       -0.9
# 18  C:/Users/George/Documents/Football Analytics/T...       -1.2
# 23  C:/Users/George/Documents/Football Analytics/T...       -1.9
# 14  C:/Users/George/Documents/Football Analytics/T...       -2.0
# 16  C:/Users/George/Documents/Football Analytics/T...       -3.6
# 22  C:/Users/George/Documents/Football Analytics/T...       -4.9
# 17  C:/Users/George/Documents/Football Analytics/T...       -5.1
# 19  C:/Users/George/Documents/Football Analytics/T...       -5.3

# %%
import matplotlib.patches as patches

plt.figure(figsize=(12, 8), dpi=200, facecolor='#141514')  # Set the facecolor to #141514

for i, team in df.iterrows():
    badge = plt.imread(team['Badge'])
    plt.imshow(badge, extent=(team['xG']-1.5, team['xG']+1.5, team['PSxG']-2.5, team['PSxG']+2.5), aspect='auto', alpha=1)

plt.plot([27, 90], [27, 90], color='#4E585F', linestyle='--', linewidth=1)

# Add labels and title
plt.xlabel('xG', color='white',weight='bold')  # Set the xlabel color to white
plt.ylabel('PSxG', color='white',weight='bold')  # Set the ylabel color to white
plt.yticks([30,40,50,60,70,80,90],['30','40','50','60','70','80','90'], color='white')  # Set the yticks color to white
plt.xticks([30,40,50,60,70,80,90],['30','40','50','60','70','80','90'],color='white')  # Set the xticks color to white
plt.ylim(27,93)
plt.xlim(29,87)
# Fill the area below and above the dotted line (at y=40)
x = np.linspace(27, 90, 100)
y = x

# Fill the area above the diagonal line
plt.fill_between(x, y, 93, color='green', alpha=0.065)

# Fill the area below the diagonal line
plt.fill_between(x, y, 25, color='red', alpha=0.065)

# Set the ticks color to white
plt.xticks(color='white')
plt.yticks(color='white')

plt.text(42, 72, 'Good', color='white', fontsize=20, fontweight='bold', alpha=0.8)
plt.text(67, 42, 'Poor', color='white', fontsize=20, fontweight='bold', alpha=0.8)

plt.subplots_adjust(top=0.85, bottom=0.25)

# Add text outside of the plot
plt.text(0.35, 1.2, f'{league} - Finishing Skill', color='yellow', fontsize=30, weight='bold', ha='center', va='center',transform=plt.gca().transAxes)
plt.text(0.9, 1.23, 'Data: @FBref | Graphic: @george__massey', color='white', fontsize=8,ha='center', va='center',transform=plt.gca().transAxes)
plt.text(0.065, 1.11, 'Good Finishing = ', weight = 'bold', color='green', fontsize=12, ha='center', va='center',transform=plt.gca().transAxes)
plt.text(0.205, 1.11, 'PSxG > xG', color='white', fontsize=12, ha='center', va='center',transform=plt.gca().transAxes)
plt.text(0.06, 1.06, 'Poor Finishing =', weight = 'bold', color='red', fontsize=12, ha='center', va='center',alpha=0.8,transform=plt.gca().transAxes)
plt.text(0.2, 1.06, 'PSxG < xG', color='white', fontsize=12, ha='center', va='center',transform=plt.gca().transAxes)
plt.text(0.15,0.14,'Average Finishing',color='grey', fontsize=8, ha='center', va='center',transform=plt.gca().transAxes, rotation=25)
# Set the plot background color to #141514
plt.gca().set_facecolor('#141514')
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import matplotlib as mpl
# Add text box in each quadrant
logo_image = plt.imread("C:\\Users\\George\\Documents\\Football Analytics\\Images\\Championship_Logo.png")

# Create an OffsetImage instance with the loaded image
logo_offsetimage = OffsetImage(logo_image, zoom=0.04)  # Adjust the zoom value as needed

# Create an AnnotationBbox instance and add it to the plot
logo_box = AnnotationBbox(logo_offsetimage, (0.98, 1.2), xycoords='axes fraction', box_alignment=(1.0, 1.0), boxcoords="offset pixels")
ax = plt.gca()
ax.add_artist(logo_box)

# Make the box invisible, but keep the image visible
logo_box.patch.set_alpha(0)

plt.show()
