# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.gridspec as gridspec
from functions import plot_heatmap

# %%
x = np.random.randint(1,101,500)

# %%
df = pd.read_csv(r"C:\Users\George\Documents\Football Analytics\Data\europaFinal.csv")
df.head()
# Out:
#    minute  second             teamId     x     y     period   type  \
# 0       0     0.0  Manchester United   0.0   0.0  FirstHalf  Start
# 1       0     0.0         Villarreal   0.0   0.0  FirstHalf  Start
# 2       0     0.0  Manchester United  49.9  50.0  FirstHalf   Pass
# 3       0     3.0  Manchester United  32.2  58.1  FirstHalf   Pass
# 4       0    32.0         Villarreal  34.4   0.0  FirstHalf   Pass
#
#         outcome  playerId  endX   endY
# 0    Successful       NaN   NaN    NaN
# 1    Successful       NaN   NaN    NaN
# 2    Successful      18.0  31.5   59.6
# 3  Unsuccessful       2.0  69.6  100.0
# 4    Successful       8.0  36.5    9.5

# %%
fig = plt.figure(figsize=(10, 10), constrained_layout=True)
gs = fig.add_gridspec(3, 4)
ax1 = fig.add_subplot(gs[0, :2])
ax1.set_title('[0,0]')
boxplot = sns.boxplot(x, ax=ax1, orient='h')

#ax2 = fig.add_subplot(gs[0, 1])
#ax2.set_title('[0,1]')

ax3 = fig.add_subplot(gs[0, 2])
ax3.set_title('[0,2]')
plot_heatmap(heat_df=df, teamId='Villarreal', stat='Pass', ax=ax3)


ax4 = fig.add_subplot(gs[0, 3])
ax4.set_title('[0,3]')
plot_heatmap(heat_df=df, teamId='Manchester United', stat='Pass', ax=ax4)

ax5 = fig.add_subplot(gs[1:3, 0])
ax5.set_title('[1,0]')

ax6 = fig.add_subplot(gs[1, 1])
ax6.set_title('[1,1]')

ax7 = fig.add_subplot(gs[1, 2])
ax7.set_title('[1,2]')

ax8 = fig.add_subplot(gs[1, 3])
ax8.set_title('[1,3]')

#ax9 = fig.add_subplot(gs[2, 0])
#ax9.set_title('[2,0]')

ax10 = fig.add_subplot(gs[2, 1])
ax10.set_title('[2,1]')

ax11 = fig.add_subplot(gs[2, 2])
ax11.set_title('[2,2]')

ax12 = fig.add_subplot(gs[2, 3])
ax12.set_title('[2,3]')
# Out:
# Text(0.5, 1.0, '[2,3]')
