# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import math
from mplsoccer import PyPizza, add_image, FontManager
from skimage import io
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import requests
from PIL import Image

# %%
playerid = 1207954
country_code = 'gb-eng'

# %%
from matplotlib.font_manager import FontProperties

# Specify your font
regular = FontProperties(fname="C:\\Users\\George\\Documents\\Football Analytics\\Kanit-Regular.ttf")  # Update the path to where the font is installed on your system
light = FontProperties(fname="C:\\Users\\George\\Documents\\Football Analytics\\Kanit-Light.ttf")  # Update the path to where the font is installed on your system
bold = FontProperties(fname="C:\\Users\\George\\Documents\\Football Analytics\\Kanit-Bold.ttf")  # Update the path to where the font is installed on your system

# %%
params ={
    'id':f'{playerid}'
}

response = requests.get('https://www.fotmob.com/api/playerData',params=params)
data = response.json()

# %%
from PIL import Image
import urllib
import requests
player = data['name']
team = 'Sunderland'#data['primaryTeam']['teamName']
team_id = '8472'# data['primaryTeam']['teamId']
league = 'League One'#data['mainLeague']['leagueName']
season = '2021/2022'#data['mainLeague']['season']
leagueid = data['mainLeague']['leagueId']
#position = data['positionDescription']['primaryPosition']['label']
try:
    age = data['playerInformation'][2]['value']['numberValue']
except:
    age = data['playerInformation'][1]['value']['numberValue']
#player_image = plt.imread(f"C:\\Users\\George\\Documents\\Football Analytics\\Images\\{player.lower()}.png")
fotmob_url = 'https://images.fotmob.com/image_resources/playerimages/'
player_image = Image.open(urllib.request.urlopen(f'{fotmob_url}{playerid:.0f}.png'))
country_image = f"C:\\Users\\George\\Documents\\Football Analytics\\National Flags\\{country_code}.png"
team_logo = io.imread(f"https://images.fotmob.com/image_resources/logo/teamlogo/{team_id}.png")
minutes_played = 3098#data['mainLeague']['stats'][4]['value']
market_value = data['playerInformation'][4]['value']['fallback']

# %%
#league = 'Superligaen'
position = 'Centre Backs'

# %%
is_recent_season = False

# %%
if is_recent_season == False:
    season_id = '2-0'
    is_first_season = 'false'
    age = 18

# %%
if is_recent_season:   
    params ={
        'playerId':f'{playerid}',
        'seasonId':f'{season}-{leagueid}'
    }

    response = requests.get('https://www.fotmob.com/api/playerStats',params=params)
    stats = response.json()

else:
    params ={
        'playerId':f'{playerid}',
        'seasonId':season_id,
        'isFirstSeason':is_first_season
    }

    response = requests.get('https://www.fotmob.com/api/playerStats',params=params)
    stats = response.json()

# %%
stats
# Out:
# {'sectionOrder': ['top-stat-card', 'shotmap', 'stats-section'],
#  'topStatCard': {'id': 'top-stat-card',
#   'type': 'stat-values',
#   'display': 'stats-group',
#   'title': 'Top stat card',
#   'localizedTitleId': 'top_stat_card',
#   'items': [{'title': 'Goals',
#     'localizedTitleId': 'goals',
#     'statValue': '1',
#     'per90': 0.02905100064557779,
#     'percentileRank': 50.4,
#     'percentileRankPer90': 54.400000000000006,
#     'statFormat': 'number'},
#    {'title': 'Assists',
#     'localizedTitleId': 'assists',
#     'statValue': '3',
#     'per90': 0.08715300193673338,
#     'percentileRank': 92,
#     'percentileRankPer90': 87.2,
#     'statFormat': 'number'},
#    {'title': 'Rating',
#     'localizedTitleId': 'rating',
#     'statValue': '7.00',
#     'per90': 7.0048571428571424,
#     'percentileRank': 71.2,
#     'percentileRankPer90': 71.2,
#     'statFormat': 'fraction'},
#    {'title': 'Matches',
#     'localizedTitleId': 'matches_uppercase',
#     'statValue': '36',
#     'per90': 36,
#     'percentileRank': 74.4,
#     'percentileRankPer90': 74.4,
#     'statFormat': 'number'},
#    {'title': 'Started',
#     'localizedTitleId': 'started',
#     'statValue': '33',
#     'per90': 33,
#     'percentileRank': 69.6,
#     'percentileRankPer90': 13.600000000000001,
#     'statFormat': 'number'},
#    {'title': 'Minutes',
#     'localizedTitleId': 'minutes_played',
#     'statValue': '3098',
#     'per90': 90,
#     'percentileRank': 76,
#     'percentileRankPer90': 100,
#     'statFormat': 'number'}]},
#  'statsSection': {'id': 'stats-section',
#   'type': 'grouped-stat-values',
#   'title': 'Season performance',
#   'localizedTitleId': 'season_performance',
#   'subTitle': 'Stats compared to other center-backs',
#   'localizedSubTitleId': 'stats_comparison_center_backs',
#   'items': [{'type': 'stat-values',
#     'display': 'stats-group',
#     'title': 'Shooting',
#     'localizedTitleId': 'shooting',
#     'items': [{'title': 'Goals',
#       'localizedTitleId': 'goals',
#       'statValue': '1',
#       'per90': 0.02905100064557779,
#       'percentileRank': 50.4,
#       'percentileRankPer90': 54.400000000000006,
#       'statFormat': 'number'},
#      {'title': 'Shots',
#       'localizedTitleId': 'shots',
#       'statValue': '12',
#       'per90': 0.3486120077469335,
#       'percentileRank': 56.00000000000001,
#       'percentileRankPer90': 29.599999999999998,
#       'statFormat': 'number'},
#      {'title': 'Shots on target',
#       'localizedTitleId': 'ShotsOnTarget',
#       'statValue': '4',
#       'per90': 0.11620400258231116,
#       'percentileRank': 59.199999999999996,
#       'percentileRankPer90': 47.199999999999996,
#       'statFormat': 'number'}]},
#    {'type': 'stat-values',
#     'display': 'stats-group',
#     'title': 'Passing',
#     'localizedTitleId': 'passing',
#     'items': [{'title': 'Assists',
#       'localizedTitleId': 'assists',
#       'statValue': '3',
#       'per90': 0.08715300193673338,
#       'percentileRank': 92,
#       'percentileRankPer90': 87.2,
#       'statFormat': 'number'},
#      {'title': 'Accurate passes',
#       'localizedTitleId': 'successful_passes',
#       'statValue': '1254',
#       'per90': 36.42995480955455,
#       'percentileRank': 86.4,
#       'percentileRankPer90': 71.2,
#       'statFormat': 'number'},
#      {'title': 'Pass accuracy',
#       'localizedTitleId': 'successful_passes_accuracy',
#       'statValue': '74.0',
#       'per90': 74.02597402597402,
#       'percentileRank': 67.2,
#       'percentileRankPer90': 67.2,
#       'statFormat': 'percent'},
#      {'title': 'Accurate long balls',
#       'localizedTitleId': 'long_balls_accurate',
#       'statValue': '152',
#       'per90': 4.415752098127824,
#       'percentileRank': 87.2,
#       'percentileRankPer90': 76,
#       'statFormat': 'number'},
#      {'title': 'Long ball accuracy',
#       'localizedTitleId': 'long_ball_succeeeded_accuracy',
#       'statValue': '38.8',
#       'per90': 38.775510204081634,
#       'percentileRank': 56.8,
#       'percentileRankPer90': 56.8,
#       'statFormat': 'percent'},
#      {'title': 'Chances created',
#       'localizedTitleId': 'chances_created',
#       'statValue': '6',
#       'per90': 0.17430600387346676,
#       'percentileRank': 51.2,
#       'percentileRankPer90': 28.799999999999997,
#       'statFormat': 'number'}]},
#    {'type': 'stat-values',
#     'display': 'stats-group',
#     'title': 'Possession',
#     'localizedTitleId': 'possession',
#     'items': [{'title': 'Dribbles',
#       'localizedTitleId': 'dribbles_succeeded',
#       'statValue': '18',
#       'per90': 0.5229180116204002,
#       'percentileRank': 96.8,
#       'percentileRankPer90': 89.60000000000001,
#       'statFormat': 'number'},
#      {'title': 'Dribbles success rate',
#       'localizedTitleId': 'won_contest_subtitle',
#       'statValue': '54.5',
#       'per90': 54.54545454545455,
#       'percentileRank': 40.8,
#       'percentileRankPer90': 40.8,
#       'statFormat': 'percent'},
#      {'title': 'Touches',
#       'localizedTitleId': 'touches',
#       'statValue': '2239',
#       'per90': 65.04519044544867,
#       'percentileRank': 85.6,
#       'percentileRankPer90': 71.2,
#       'statFormat': 'number'},
#      {'title': 'Touches in opposition box',
#       'localizedTitleId': 'touches_opp_box',
#       'statValue': '20',
#       'per90': 0.5810200129115558,
#       'percentileRank': 48,
#       'percentileRankPer90': 21.6,
#       'statFormat': 'number'},
#      {'title': 'Dispossessed',
#       'localizedTitleId': 'dispossessed',
#       'statValue': '11',
#       'per90': 0.3195610071013557,
#       'percentileRank': 14.399999999999999,
#       'percentileRankPer90': 31.2,
#       'statFormat': 'number'},
#      {'title': 'Fouls won',
#       'localizedTitleId': 'fouls_won',
#       'statValue': '22',
#       'per90': 0.6391220142027114,
#       'percentileRank': 68,
#       'percentileRankPer90': 46.400000000000006,
#       'statFormat': 'number'},
#      {'title': 'Penalties awarded',
#       'localizedTitleId': 'penalty_won_title',
#       'statValue': '1',
#       'per90': 0.02905100064557779,
#       'percentileRank': 100,
#       'percentileRankPer90': 96.8,
#       'statFormat': 'number'}]},
#    {'type': 'stat-values',
#     'display': 'stats-group',
#     'title': 'Defending',
#     'localizedTitleId': 'defending',
#     'items': [{'title': 'Penalties conceded',
#       'localizedTitleId': 'penalty_conceded_title',
#       'statValue': '1',
#       'per90': 0.02905100064557779,
#       'percentileRank': 2.4,
#       'percentileRankPer90': 20.8,
#       'statFormat': 'number'},
#      {'title': 'Tackles won',
#       'localizedTitleId': 'tackles_succeeded',
#       'statValue': '35',
#       'per90': 1.0167850225952226,
#       'percentileRank': 84,
#       'percentileRankPer90': 72.8,
#       'statFormat': 'number'},
#      {'title': 'Tackles won %',
#       'localizedTitleId': 'tackles_succeeded_percent',
#       'statValue': '61.4',
#       'per90': 61.40350877192982,
#       'percentileRank': 41.6,
#       'percentileRankPer90': 41.6,
#       'statFormat': 'percent'},
#      {'title': 'Duels won',
#       'localizedTitleId': 'duel_won',
#       'statValue': '173',
#       'per90': 5.025823111684958,
#       'percentileRank': 70.39999999999999,
#       'percentileRankPer90': 32.800000000000004,
#       'statFormat': 'number'},
#      {'title': 'Duels won %',
#       'localizedTitleId': 'duel_won_percent',
#       'statValue': '55.6',
#       'per90': 55.62700964630225,
#       'percentileRank': 23.200000000000003,
#       'percentileRankPer90': 23.200000000000003,
#       'statFormat': 'percent'},
#      {'title': 'Aerials won',
#       'localizedTitleId': 'aerials_won',
#       'statValue': '77',
#       'per90': 2.23692704970949,
#       'percentileRank': 53.6,
#       'percentileRankPer90': 18.4,
#       'statFormat': 'number'},
#      {'title': 'Aerials won %',
#       'localizedTitleId': 'aerials_won_percent',
#       'statValue': '53.1',
#       'per90': 53.10344827586207,
#       'percentileRank': 27.200000000000003,
#       'percentileRankPer90': 27.200000000000003,
#       'statFormat': 'percent'},
#      {'title': 'Interceptions',
#       'localizedTitleId': 'interceptions',
#       'statValue': '47',
#       'per90': 1.3653970303421563,
#       'percentileRank': 82.39999999999999,
#       'percentileRankPer90': 57.599999999999994,
#       'statFormat': 'number'},
#      {'title': 'Blocked scoring attempt',
#       'localizedTitleId': 'shot_blocked',
#       'statValue': '3',
#       'per90': 0.08715300193673338,
#       'percentileRank': 54.400000000000006,
#       'percentileRankPer90': 42.4,
#       'statFormat': 'number'},
#      {'title': 'Fouls committed',
#       'localizedTitleId': 'fouls',
#       'statValue': '27',
#       'per90': 0.7843770174306004,
#       'percentileRank': 76.8,
#       'percentileRankPer90': 48,
#       'statFormat': 'number'},
#      {'title': 'Recoveries',
#       'localizedTitleId': 'recoveries',
#       'statValue': '184',
#       'per90': 5.345384118786314,
#       'percentileRank': 84.8,
#       'percentileRankPer90': 82.39999999999999,
#       'statFormat': 'number'},
#      {'title': 'Possession won final 3rd',
#       'localizedTitleId': 'poss_won_att_3rd_team_title',
#       'statValue': '3',
#       'per90': 0.08715300193673338,
#       'percentileRank': 72,
#       'percentileRankPer90': 66.4,
#       'statFormat': 'number'},
#      {'title': 'Dribbled past',
#       'localizedTitleId': 'dribbled_past',
#       'statValue': '19',
#       'per90': 0.551969012265978,
#       'percentileRank': 0.8,
#       'percentileRankPer90': 7.199999999999999,
#       'statFormat': 'number'}]},
#    {'type': 'stat-values',
#     'display': 'stats-group',
#     'title': 'Discipline',
#     'localizedTitleId': 'discipline',
#     'items': [{'title': 'Yellow cards',
#       'localizedTitleId': 'yellow_cards',
#       'statValue': '4',
#       'per90': 0.11620400258231116,
#       'percentileRank': 36,
#       'percentileRankPer90': 64,
#       'statFormat': 'number'},
#      {'title': 'Red cards',
#       'localizedTitleId': 'red_cards',
#       'statValue': '0',
#       'per90': 0,
#       'percentileRank': 100,
#       'percentileRankPer90': 100,
#       'statFormat': 'number'}]}]},
#  'shotmap': None,
#  'keeperShotmap': None}

# %%
df = pd.DataFrame()

# %%
try:
    for x in range(len(stats['statsSection']['items'])):
        df2 = pd.DataFrame(stats['statsSection']['items'][x]['items'])
        df = pd.concat([df,df2], axis = 0) 
except: 
    for x in range(len(data['firstSeasonStats']['statsSection']['items'])):
        temp_df = pd.DataFrame(data['firstSeasonStats']['statsSection']['items'][x]['items'])
        df = pd.concat([df,temp_df])

# %%
df.reset_index(inplace=True)

# %%
df = df[['title','percentileRankPer90','per90']]

# %%
df['title'].unique()
# Out:
# array(['Goals', 'Shots', 'Shots on target', 'Assists', 'Accurate passes',
#        'Pass accuracy', 'Accurate long balls', 'Long ball accuracy',
#        'Chances created', 'Dribbles', 'Dribbles success rate', 'Touches',
#        'Touches in opposition box', 'Dispossessed', 'Fouls won',
#        'Penalties awarded', 'Penalties conceded', 'Tackles won',
#        'Tackles won %', 'Duels won', 'Duels won %', 'Aerials won',
#        'Aerials won %', 'Interceptions', 'Blocked scoring attempt',
#        'Fouls committed', 'Recoveries', 'Possession won final 3rd',
#        'Dribbled past', 'Yellow cards', 'Red cards'], dtype=object)

# %%
df['per90'] = df['per90'].astype(float)
df['per90'] = round(df['per90'],1)

# %%
df
# Out:
#                         title  percentileRankPer90  per90
# 0                       Goals                 54.4    0.0
# 1                       Shots                 29.6    0.3
# 2             Shots on target                 47.2    0.1
# 3                     Assists                 87.2    0.1
# 4             Accurate passes                 71.2   36.4
# 5               Pass accuracy                 67.2   74.0
# 6         Accurate long balls                 76.0    4.4
# 7          Long ball accuracy                 56.8   38.8
# 8             Chances created                 28.8    0.2
# 9                    Dribbles                 89.6    0.5
# 10      Dribbles success rate                 40.8   54.5
# 11                    Touches                 71.2   65.0
# 12  Touches in opposition box                 21.6    0.6
# 13               Dispossessed                 31.2    0.3
# 14                  Fouls won                 46.4    0.6
# 15          Penalties awarded                 96.8    0.0
# 16         Penalties conceded                 20.8    0.0
# 17                Tackles won                 72.8    1.0
# 18              Tackles won %                 41.6   61.4
# 19                  Duels won                 32.8    5.0
# 20                Duels won %                 23.2   55.6
# 21                Aerials won                 18.4    2.2
# 22              Aerials won %                 27.2   53.1
# 23              Interceptions                 57.6    1.4
# 24    Blocked scoring attempt                 42.4    0.1
# 25            Fouls committed                 48.0    0.8
# 26                 Recoveries                 82.4    5.3
# 27   Possession won final 3rd                 66.4    0.1
# 28              Dribbled past                  7.2    0.6
# 29               Yellow cards                 64.0    0.1
# 30                  Red cards                100.0    0.0

# %%
if position == 'Centre Backs':
    params = ['Goals',
    'Accurate passes',
    'Pass accuracy',
    'Accurate long balls',
    'Dispossessed',
    'Tackles won',
    'Tackles won %',
    'Aerials won',
    'Aerials won %',
    'Interceptions',
    'Fouls committed',
    'Dribbled past']

# %%
df = df[df['title'].isin(params)]
df.reset_index(inplace=True)
df.drop('index', axis = 1, inplace=True)
# Out:
# C:\Users\dmsta\AppData\Local\Temp\ipykernel_468\1470265099.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('index', axis = 1, inplace=True)

# %%
df['percentileRankPer90'] = df['percentileRankPer90'].astype(int)
values = df['percentileRankPer90'].tolist()
values
# Out:
# C:\Users\dmsta\AppData\Local\Temp\ipykernel_468\450733561.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['percentileRankPer90'] = df['percentileRankPer90'].astype(int)
# [54, 71, 67, 76, 31, 72, 41, 18, 27, 57, 48, 7]

# %%
font_normal = FontManager('https://raw.githubusercontent.com/googlefonts/roboto/main/'
                          'src/hinted/Roboto-Regular.ttf')
font_italic = FontManager('https://raw.githubusercontent.com/googlefonts/roboto/main/'
                          'src/hinted/Roboto-Italic.ttf')
font_bold = FontManager('https://raw.githubusercontent.com/google/fonts/main/apache/robotoslab/'
                        'RobotoSlab[wght].ttf')

# %%
todays_date = pd.to_datetime('today').strftime('%d %B %Y')

# %%
# color for the slices and text
slice_colors = ["#1A78CF"] * 1 + ["#FF9300"] * 4 + ["#D70232"] * 7
text_colors = ["#000000"] * 12 + ["#F2F2F2"] * 0

# instantiate PyPizza class
baker = PyPizza(
    params=params,                  # list of parameters
    background_color="#EBEBEB",     # background color
    straight_line_color="#EBEBEB",  # color for straight lines
    straight_line_lw=1,             # linewidth for straight lines
    last_circle_lw=0,               # linewidth of last circle
    other_circle_lw=0,              # linewidth for other circles
    inner_circle_size=20            # size of inner circle
)

# plot pizza
fig, ax = baker.make_pizza(
    values,                          # list of values
    figsize=(10, 8),                # adjust figsize according to your need
    color_blank_space="same",        # use same color to fill blank space
    slice_colors=slice_colors,       # color for individual slices
    value_colors=text_colors,        # color for the value-text
    value_bck_colors=slice_colors,   # color for the blank spaces
    blank_alpha=0.4,                 # alpha for blank-space colors
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),                               # values to be used when plotting slices
    kwargs_params=dict(
        color="black", fontsize=11,
        fontproperties=regular, va="center"
    ),                               # values to be used when adding parameter
    kwargs_values=dict(
        color="black", fontsize=11,
        fontproperties=regular,
        zorder=3,
        bbox=dict(
            edgecolor="black", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )                                # values to be used when adding parameter-values
)

# add title
fig.text(
    0.515, 1.08, f"{player}", size=40,
    ha="center", color="#005E9C", weight = 'bold',
    fontproperties=bold
)

# add subtitle
fig.text(
    0.515, 1,
    f"{team} | 90's played {round(minutes_played/90, 1)} | Age: {age} | Value: {market_value}\nPer 90 Percentile Rank vs {league} {position} | Season {season}",
    size=14,
    ha="center", color="black",
    fontproperties=regular

)

# add credits
CREDIT_1 = "Graphic: @george__massey | Data: FotMob"

fig.text(
    0.95, 0.02, f"{CREDIT_1}", size=10,
    color="black",
    ha="right",
    fontproperties=light
)

fig.text(
    0.1, 0.02, f"Created: {todays_date}", size=10,
    color="black",
    ha="left",
    fontproperties=bold
)

# add text
fig.text(
    0.34, 0.96, "Attacking                 Possession                 Defending", size=14,
    color="black", fontproperties=regular
)

# add rectangles
fig.patches.extend([
    plt.Rectangle(
        (0.31, 0.9575), 0.025, 0.021, fill=True, color="#1a78cf",
        transform=fig.transFigure, figure=fig
    ),
    plt.Rectangle(
        (0.47, 0.9575), 0.025, 0.021, fill=True, color="#ff9300",
        transform=fig.transFigure, figure=fig
    ),
    plt.Rectangle(
        (0.645, 0.9575), 0.025, 0.021, fill=True, color="#d70232",
        transform=fig.transFigure, figure=fig
    ),
])

img_offset = OffsetImage(team_logo, zoom=0.28)
img_box = AnnotationBbox(img_offset, (1.15,1.35), xycoords='axes fraction', box_alignment=(1.0, 1.0), boxcoords="offset pixels", frameon=False, pad=0.1)
ax = plt.gca()
ax.add_artist(img_box)
img_box.patch.set_alpha(0)

# add image
ax_image = add_image(
    player_image, fig, left=0.4578, bottom=0.445, width=0.11, height=0.11
)   # these values might differ when you are plotting

ax2 = fig.add_axes([.13,1.04,.08,.12])
ax2.axis('off')
img = Image.open(country_image)
ax2.imshow(img)

fig.savefig(
    f"C:/Users/George/Documents/Football Analytics/Visuals/{player} {team}.png",
    facecolor=ax.get_facecolor(),
    dpi=600,
    bbox_inches="tight"
)

plt.show()
