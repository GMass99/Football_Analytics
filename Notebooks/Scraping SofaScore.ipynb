# %% [markdown]
# ## To Add a different Game just change the match id in the url (11367957)

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.sofascore.com/norwich-city-rotherham-united/nsnf#id:11367957'
response = requests.get(
    url,
    headers = {
        'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
    })

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'html')

# %%
soup.select('g[cursor="pointer"]')
# Out:
# []

# %%
import requests

headers = {
    'authority': 'api.sofascore.com',
    'accept': '*/*',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'cache-control': 'max-age=0',
    'if-none-match': 'W/"04ac682c78"',
    'origin': 'https://www.sofascore.com',
    'referer': 'https://www.sofascore.com/',
    'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
}

response = requests.get('https://api.sofascore.com/api/v1/event/11367957/shotmap', headers=headers)

# %%
response.status_code
# Out:
# 304

# %%
headers['If-Modified-Since'] = 'Tue, 12 Mar 2024 00:00:00 GMT'

# %%
response = requests.get('https://api.sofascore.com/api/v1/event/11367957/shotmap', headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
shots = response.json()

# %%
shots
# Out:
# {'shotmap': [{'player': {'name': 'Arvin Appiah',
#     'slug': 'arvin-appiah',
#     'shortName': 'A. Appiah',
#     'position': 'F',
#     'jerseyNumber': '30',
#     'userCount': 190,
#     'id': 934229,
#     'fieldTranslations': {'nameTranslation': {'ar': 'أبياه ، أرفين'},
#      'shortNameTranslation': {'ar': 'أ. ، أرفين'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 10.5, 'y': 26.4, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 47.8, 'z': 19},
#    'blockCoordinates': {'x': 9.8, 'y': 28.2, 'z': 0},
#    'xg': 0.016520304605365,
#    'id': 2568151,
#    'time': 90,
#    'timeSeconds': 5366,
#    'draw': {'start': {'x': 26.4, 'y': 10.5},
#     'block': {'x': 28.2, 'y': 9.8},
#     'end': {'x': 52.2, 'y': 0},
#     'goal': {'x': 52.2, 'y': 81}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 34,
# ...
