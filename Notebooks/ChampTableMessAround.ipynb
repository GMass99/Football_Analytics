# %%
import pandas as pd

# %%
df = pd.read_excel("C:/Users/George/Documents/Football Analytics/Data/ChampTableHistory.xlsx")

# %%
pd.set_option('display.max_rows', 30)

# %%
#df = df.dropna(subset=['xGD'])

# %%
df
# Out:
#      Pos            Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP  \
# 0      1  Manchester City  46  31   6   9  108  52  56   99    2.15
# 1      2        West Brom  46  27   8  11   61  29  32   89    1.93
# 2      3           Wolves  46  25  11  10   76  43  33   86    1.87
# 3      4         Millwall  46  22  11  13   69  48  21   77    1.67
# 4      5  Birmingham City  46  21  13  12   70  49  21   76    1.65
# ..   ...              ...  ..  ..  ..  ..  ...  ..  ..  ...     ...
# 523   20              QPR  46  13  11  22   44  71 -27   50    1.09
# 524   21     Cardiff City  46  13  10  23   41  58 -17   49    1.07
# 525   22          Reading  46  13  11  22   46  68 -22   50    1.09
# 526   23        Blackpool  46  11  11  24   48  72 -24   44    0.96
# 527   24   Wigan Athletic  46  10  15  21   38  65 -27   45    0.98
#
#      Attendance             Top Team Scorer     Goalkeeper  \
# 0       33059.0           Shaun Goater - 28   Nicky Weaver
# ...

# %%
#df['GD - xGD'] = df['GD'] - df['xGD']

# %%
#df = df.sort_values(by='GD - xGD', ascending=True)

# %%
#df = df.sort_values(by='xGD', ascending=False)

# %%
df.tail(30)
# Out:
#      Pos            Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP  \
# 498   19        Hull City  46  14   9  23  41  54 -13   51    1.11
# 499   20  Birmingham City  46  11  14  21  50  75 -25   47    1.02
# 500   21          Reading  46  13   8  25  54  87 -33   41    0.89
# 501   22    P'borough Utd  46   9  10  27  43  87 -44   37    0.80
# 502   23     Derby County  46  14  13  19  45  53  -8   34    0.74
# 503   24         Barnsley  46   6  12  28  33  73 -40   30    0.65
# 504    1          Burnley  46  29  14   3  87  35  52  101    2.20
# 505    2    Sheffield Utd  46  28   7  11  73  39  34   91    1.98
# 506    3       Luton Town  46  21  17   8  57  39  18   80    1.74
# 507    4    Middlesbrough  46  22   9  15  84  56  28   75    1.63
# 508    5    Coventry City  46  18  16  12  58  46  12   70    1.52
# 509    6       Sunderland  46  18  15  13  68  55  13   69    1.50
# 510    7        Blackburn  46  20   9  17  52  54  -2   69    1.50
# ...

# %%
playoff_df = df[df['Pos'].isin(range(1,7))]

# %%
df = playoff_df

# %%
df[df['GA']>60]
# Out:
#      Pos           Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP  Attendance  \
# 52     5    Ipswich Town  46  21  10  15  84  72  12   73    1.59     24520.0
# 53     6  Crystal Palace  46  21  10  15  71  61  10   73    1.59     17344.0
# 268    5  Crystal Palace  46  19  15  12  73  62  11   72    1.57     17280.0
# 362    3         Reading  46  26   7  13  68  64   4   85    1.85     17505.0
# 411    4       West Brom  46  23  11  12  87  62  25   80    1.74     24148.0
# 412    5     Aston Villa  46  20  16  10  82  61  21   76    1.65     36027.0
#
#           Top Team Scorer        Goalkeeper                    Notes    xG  \
# 52       Darren Bent - 15      Kelvin Davis            → Semi-finals   NaN
# 53    Andrew Johnson - 27  Cédric Berthelin  Promoted, → Semi-finals   NaN
# 268     Glenn Murray - 30    Julián Speroni  Promoted, → Semi-finals   NaN
# 362  Yann Kermorgant - 18      Ali Al-Habsi            → Semi-finals   NaN
# ...

# %%
df[df['Pos']== 4]
# Out:
#      Pos            Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP  \
# 3      4         Millwall  46  22  11  13  69  48  21   77    1.67
# 27     4          Reading  46  25   4  17  61  46  15   79    1.72
# 51     4         West Ham  46  19  17  10  67  45  22   74    1.61
# 75     4     Derby County  46  22  10  14  71  60  11   76    1.65
# 99     4          Preston  46  20  20   6  59  30  29   80    1.74
# 123    4        West Brom  46  22  10  14  81  55  26   76    1.65
# 147    4     Bristol City  46  20  14  12  54  53   1   74    1.61
# 171    4          Reading  46  21  14  11  72  40  32   77    1.67
# 195    4     Cardiff City  46  22  10  14  73  54  19   76    1.65
# 219    4     Cardiff City  46  23  11  12  76  54  22   80    1.74
# 243    4  Birmingham City  46  20  16  10  78  51  27   76    1.65
# 267    4         Brighton  46  19  18   9  69  43  26   75    1.63
# 291    4              QPR  46  23  11  12  60  44  16   80    1.74
# ...

# %%
promoted_df = df[df['Notes'].isin(['Promoted, → Semi-finals','Promoted, → Promotion play-offs'])]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot the distribution of positions
sns.countplot(data=promoted_df, x='Pos')
plt.title('Distribution of Positions')
plt.xlabel('Position')
plt.ylabel('Count')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=90)

# Show the plot
plt.show()
