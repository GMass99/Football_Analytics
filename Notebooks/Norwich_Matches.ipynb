# %%
import pandas as pd
import requests

# %%
df = pd.read_html('https://fbref.com/en/squads/1c781004/Norwich-City-Stats', attrs = {"id" : "matchlogs_for"})[0]

# %%
df = df[df['Comp'] == 'Championship'].reset_index(drop=True)

# %%
row_indices = list(range(0, 14)) + list(range(27, 30)) + list(range(39, 41)) + list(range(42, 45))
df_duffy_gibbo = df.loc[row_indices, :]
num_rows = df_duffy_gibbo.shape[0]
num_rows
# Out:
# 22

# %%
row_indices = list(range(16, 18))
df_duffy_batth = df.loc[row_indices, :]
num_rows = df_duffy_batth.shape[0]
num_rows
# Out:
# 2

# %%
row_indices = list(range(18, 24)) + list(range(26, 27))
df_kenny_duffy = df.loc[row_indices, :]
num_rows = df_kenny_duffy.shape[0]
num_rows
# Out:
# 7

# %%
row_indices = list(range(24, 25)) + list(range(41, 42))
df_gibson_batth = df.loc[row_indices, :]
num_rows = df_gibson_batth.shape[0]
num_rows
# Out:
# 2

# %%
row_indices = list(range(30, 31)) + list(range(33, 36))
df_gibson_hanley = df.loc[row_indices, :]
num_rows = df_gibson_hanley.shape[0]
num_rows
# Out:
# 4

# %%
row_indices = list(range(31, 32)) + list(range(36, 39))
df_gibson_sorenson = df.loc[row_indices, :]
num_rows = df_gibson_sorenson.shape[0]
num_rows
# Out:
# 4

# %%
(df_gibson_sorenson[df_gibson_sorenson['Result'] == 'W'].shape[0])*3 + df_gibson_sorenson[df_gibson_sorenson['Result'] == 'D'].shape[0]
# Out:
# 12

# %%
df_gibson_batth['xGA'].sum().round(2)
# Out:
# 3.7

# %%
df
# Out:
#           Date   Time          Comp         Round  Day Venue Result   GF   GA  \
# 0   2023-08-05  15:00  Championship   Matchweek 1  Sat  Home      W  2.0  1.0
# 1   2023-08-12  15:00  Championship   Matchweek 2  Sat  Away      D  4.0  4.0
# 2   2023-08-20  12:00  Championship   Matchweek 3  Sun  Home      W  3.0  1.0
# 3   2023-08-26  15:00  Championship   Matchweek 4  Sat  Away      W  4.0  0.0
# 4   2023-09-02  15:00  Championship   Matchweek 5  Sat  Away      L  1.0  2.0
# 5   2023-09-16  15:00  Championship   Matchweek 6  Sat  Home      W  1.0  0.0
# 6   2023-09-20  20:00  Championship   Matchweek 7  Wed  Home      L  0.0  2.0
# 7   2023-09-23  15:00  Championship   Matchweek 8  Sat  Away      L  2.0  6.0
# 8   2023-09-30  15:00  Championship   Matchweek 9  Sat  Home      W  2.0  0.0
# 9   2023-10-04  19:45  Championship  Matchweek 10  Wed  Away      L  1.0  2.0
# 10  2023-10-07  15:00  Championship  Matchweek 11  Sat  Away      D  1.0  1.0
# ...
